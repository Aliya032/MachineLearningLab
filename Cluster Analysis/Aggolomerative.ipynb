# %% [markdown]
# # Agglomerative Clustering

# %% [markdown]
# **Demonstration of Clustering algorithms using Hierarchial Algorithm (Agglomereative)**

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.cluster import AgglomerativeClustering
from matplotlib.colors import ListedColormap
import seaborn as sns
from scipy.cluster.hierarchy import fcluster, linkage, dendrogram

# %% [markdown]
# ### Reading the dataset

# %%
dataset = pd.read_csv('C:/Users/hassa/OneDrive/Desktop/VI sem/ML/lab-external/dataset/Logistic_Iris.csv')

# %% [markdown]
# ### Describing input

# %%
x = dataset.iloc[:,[0,1,2,3]].values

# %% [markdown]
# ### Drawing pairplot

# %%
sns.pairplot(dataset)
# Out:
# C:\Users\hassa\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Finding the optimum number of clusters for k-means classfication

# %%
Elbow = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, max_iter = 300, init = 'k-means++', n_init = 10, random_state = 0)
    kmeans.fit(x)
    Elbow.append(kmeans.inertia_)

# %% [markdown]
# ### plotting the graph for elbow method

# %%
plt.plot(range(1,11), Elbow, marker = 'o')
plt.title('The Elbow Method')
plt.xlabel("Number of clusters")
plt.ylabel('Elbow')
plt.show()

# %% [markdown]
# ### Generating distance matrix

# %%
distance_matrix = linkage(x, metric = 'euclidean', method = 'ward')

# %% [markdown]
# ### Creating a dendrogramf for the distance matrix

# %%
dn = dendrogram(distance_matrix)
plt.show()

# %% [markdown]
# ### Trying out with 2 Clusters

# %% [markdown]
# **First trying out with 2 clusters, let's see how we get that line**

# %%
dn2 = dendrogram(distance_matrix)
plt.axhline(y=13, color = 'r', linestyle = '--')
plt.ylim(0, 15)
plt.show()

# %% [markdown]
# **Checking what kind of scatter plot we get if we select two clusters**

# %%
cluster = AgglomerativeClustering(n_clusters= 2, affinity = 'euclidean', linkage = 'ward')
cluster.fit_predict(x)
plt.title('Agglomerative Clustering - 2 Clusters')
plt.scatter(x[:,2], x[:,3], c = cluster.labels_, label = cluster.labels_)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# ### Trying out with 3 clusters

# %%
dn3 = dendrogram(distance_matrix)
plt.axhline(y=8, color = 'r', linestyle = '--')
plt.ylim(0, 15)
plt.show()

# %%
cluster = AgglomerativeClustering(n_clusters= 3, affinity = 'euclidean', linkage = 'ward')
cluster.fit_predict(x)
plt.title('Agglomerative Clustering - 3 Clusters')
plt.scatter(x[:,2], x[:,3], c = cluster.labels_, label = cluster.labels_)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# ### Trying out with 5 clusters

# %%
dn5 = dendrogram(distance_matrix)
plt.axhline(y = 4.5, color = 'r', linestyle = '--')
plt.ylim(0,15)
plt.show()

# %%
cluster5 = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
cluster5.fit_predict(x)
plt.title('Agglomerative Clustering - 5 Clusters')
plt.scatter(x[:,2], x[:,3], c = cluster5.labels_)
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %% [markdown]
# ### ---------------------------------------------------
